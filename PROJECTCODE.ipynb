# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Online-Store-Orders.csv')
df.head(50)
# Out:
#       OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 0   ORD200000  2023-01-04     C72649  Monitor         5     570.62
# 1   ORD200001  2024-08-23     C75739    Phone         2     151.35
# 2   ORD200002  2024-02-27     C81728   Tablet         5     550.68
# 3   ORD200003  2023-10-15     C33540    Chair         1     273.19
# 4   ORD200004  2025-05-08     C81840  Printer         4     626.01
# 5   ORD200005  2023-10-23     C37249    Phone         2     245.86
# 6   ORD200006  2025-06-17     C83492   Laptop         1     664.42
# 7   ORD200007  2023-05-12     C41460  Monitor         5     149.55
# 8   ORD200008  2025-04-02     C26817    Phone         2     134.28
# 9   ORD200009  2023-11-21     C31946     Desk         4     509.38
# 10  ORD200010  2023-12-29     C43443   Tablet         5     625.97
# 11  ORD200011  2024-02-17     C93861  Monitor         3      49.14
# 12  ORD200012  2024-10-15     C38785  Monitor         2     180.50
# ...

# %%
df.columns
# Out:
# Index(['OrderID', 'Date', 'CustomerID', 'Product', 'Quantity', 'UnitPrice',
#        'ShippingAddress', 'PaymentMethod', 'OrderStatus', 'TrackingNumber',
#        'ItemsInCart', 'CouponCode', 'ReferralSource', 'TotalPrice'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# OrderID              0
# Date                 0
# CustomerID           0
# Product              0
# Quantity             0
# UnitPrice            0
# ShippingAddress      0
# PaymentMethod        0
# OrderStatus          0
# TrackingNumber       0
# ItemsInCart          0
# CouponCode         309
# ReferralSource       0
# TotalPrice           0
# dtype: int64

# %%
df['CouponCode'].head(50)
# Out:
# 0       SAVE10
# 1       SAVE10
# 2     FREESHIP
# 3       SAVE10
# 4       SAVE10
# 5       SAVE10
# 6       SAVE10
# 7     FREESHIP
# 8          NaN
# 9       SAVE10
# 10    WINTER15
# 11      SAVE10
# 12    FREESHIP
# 13    FREESHIP
# 14      SAVE10
# 15         NaN
# 16    FREESHIP
# 17         NaN
# 18      SAVE10
# 19      SAVE10
# 20    WINTER15
# 21         NaN
# 22      SAVE10
# 23    FREESHIP
# 24    WINTER15
# 25    WINTER15
# 26         NaN
# 27    WINTER15
# 28         NaN
# 29      SAVE10
# 30      SAVE10
# 31         NaN
# 32         NaN
# 33    WINTER15
# 34    WINTER15
# 35      SAVE10
# 36         NaN
# 37      SAVE10
# 38      SAVE10
# 39      SAVE10
# 40    FREESHIP
# 41    FREESHIP
# 42         NaN
# 43         NaN
# 44    FREESHIP
# 45      SAVE10
# 46    FREESHIP
# 47    FREESHIP
# 48         NaN
# 49      SAVE10
# Name: CouponCode, dtype: object

# %%
df['CouponCode']=df['CouponCode'].fillna('No Coupon')

# %%
df['CouponCode'].head(50)
# Out:
# 0        SAVE10
# 1        SAVE10
# 2      FREESHIP
# 3        SAVE10
# 4        SAVE10
# 5        SAVE10
# 6        SAVE10
# 7      FREESHIP
# 8     No Coupon
# 9        SAVE10
# 10     WINTER15
# 11       SAVE10
# 12     FREESHIP
# 13     FREESHIP
# 14       SAVE10
# 15    No Coupon
# 16     FREESHIP
# 17    No Coupon
# 18       SAVE10
# 19       SAVE10
# 20     WINTER15
# 21    No Coupon
# 22       SAVE10
# 23     FREESHIP
# 24     WINTER15
# 25     WINTER15
# 26    No Coupon
# 27     WINTER15
# 28    No Coupon
# 29       SAVE10
# 30       SAVE10
# 31    No Coupon
# 32    No Coupon
# 33     WINTER15
# 34     WINTER15
# 35       SAVE10
# 36    No Coupon
# 37       SAVE10
# 38       SAVE10
# 39       SAVE10
# 40     FREESHIP
# 41     FREESHIP
# 42    No Coupon
# 43    No Coupon
# 44     FREESHIP
# 45       SAVE10
# 46     FREESHIP
# 47     FREESHIP
# 48    No Coupon
# 49       SAVE10
# Name: CouponCode, dtype: object

# %% [markdown]
# #Replaced 309 missing values with "No Coupon".
# #In an online store environment, a missing coupon code often indicates that no promotional code was applied during checkout.
# #This preserved all transaction records while making the column easier to analyze.

# %%
duplicate_ids = df['OrderID'].duplicated().sum()

print(f"Duplicate Order IDs: {duplicate_ids}")
# Out:
# Duplicate Order IDs: 0
